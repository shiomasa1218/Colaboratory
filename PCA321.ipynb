# %% [markdown]
# <a href="https://colab.research.google.com/github/shiomasa1218/Colaboratory/blob/master/PCA321.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# drive mean root directory of  google drive
# !ls ./gdrive/'My Drive'/'Kumamoto-Univ'/'Graduationwork'/'exefolder'/'test_folder_name'
# Out:
# ls: cannot access './gdrive/My Drive/Kumamoto-Univ/Graduationwork/exefolder/test_folder_name': No such file or directory

# %%
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# check auth
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
cd gdrive/'My Drive'/'Kumamoto-Univ'/'Graduationwork'/'exefolder'/
# Out:
# /content/gdrive/My Drive/Kumamoto-Univ/Graduationwork/exefolder

# %%
import numpy as np
import os
import scipy.fftpack
from pylab import *
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt 
from scipy.signal import butter, filtfilt 
import math
import csv
from sklearn.decomposition import PCA



# 訓練データのフォルダのパス
train_folder_name = "train_folder_name"

# # 検証データのフォルダのパス
# test_folder_name = "test_folder_name"


trainFolder = os.listdir(train_folder_name)
# testFolder = os.listdir(test_folder_name)

os.makedirs("train_pca321",exist_ok=True)
for i,d in enumerate(trainFolder):
   
    if d != ".DS_Store":
        dir_path = 'train_pca321/' + d +'_pca321'
        os.makedirs(dir_path,exist_ok=True)
        #フォルダ内のファイルのリストを取得
        files = os.listdir(train_folder_name + '/'+d)
        print(files)
        #ファイル毎にみる
        for f in files:
                            
            #.DS_Storeをどかす
            if f != ".DS_Store":
                #どのファイルを見ているか確認用
                print("load:"+f)

                datafile_path = train_folder_name + '/' + d+'/'+f

                #csvから読み込み
                data = np.loadtxt(datafile_path, delimiter=",")     #pbldata用

                #データ取り出し
                csv_x = data[1, :]
#                 csv_x = csv_x.reshape(len(csv_x),1)
                csv_y = data[2, :]
#                 csv_y = csv_y.reshape(len(csv_x),1)
                csv_z = data[3, :]
#                 csv_y = csv_y.reshape(len(csv_x),1)
                
                csv = []
                csv.append(csv_x)
                csv.append(csv_y)
                csv.append(csv_z)
                csv=np.array(csv)
                csv=csv.T
                
                pca = PCA(n_components = 1)
                pca.fit(csv)
                csv_pca= pca.transform(csv)

#                 # 主成分分析後のサイズ
                print(csv_pca.shape)
                
                csv_pca = csv_pca.reshape(1,len(csv_pca))
                print(csv_pca)
                csv_pca = csv_pca[0,:]
                print(csv_pca)
                
                PCA321 = []
                
                PCA321.append(csv_pca)
                
                path_w = 'train_pca321/' + d +"_pca321" +'/' + f
                path_w = path_w.replace(".csv" , "_pca321.csv")
                np.savetxt(path_w, PCA321, delimiter=",")
               

            else:
                print(".ds_storeを除去")
    else:
        print("ds_storeを抹殺")
        
print("transformed")
# Out:
# ['twhitetile1_217.csv', 'twhitetile1_216.csv', 'twhitetile1_215.csv', 'twhitetile1_228.csv', 'twhitetile1_229.csv', 'twhitetile1_214.csv', 'twhitetile1_212.csv', 'twhitetile1_213.csv', 'twhitetile1_211.csv', 'twhitetile1_239.csv', 'twhitetile1_276.csv', 'twhitetile1_288.csv', 'twhitetile1_277.csv', 'twhitetile1_28.csv', 'twhitetile1_238.csv', 'twhitetile1_210.csv', 'twhitetile1_263.csv', 'twhitetile1_262.csv', 'twhitetile1_289.csv', 'twhitetile1_265.csv', 'twhitetile1_29.csv', 'twhitetile1_248.csv', 'twhitetile1_249.csv', 'twhitetile1_274.csv', 'twhitetile1_260.csv', 'twhitetile1_261.csv', 'twhitetile1_275.csv', 'twhitetile1_271.csv', 'twhitetile1_259.csv', 'twhitetile1_258.csv', 'twhitetile1_295.csv', 'twhitetile1_270.csv', 'twhitetile1_264.csv', 'twhitetile1_242.csv', 'twhitetile1_273.csv', 'twhitetile1_281.csv', 'twhitetile1_267.csv', 'twhitetile1_21.csv', 'twhitetile1_272.csv', 'twhitetile1_266.csv', 'twhitetile1_256.csv', 'twhitetile1_243.csv', 'twhitetile1_255.csv', 'twhitetile
# ...

# %%
print(csv_pca)
csv = []
csv.append(csv_pca)
print(csv)
print(PCA321)
# Out:
# [-42.87660614 -44.97176117 -47.02675152 ...  -6.58415312  -8.65102798
#  -13.53255128]
# [array([-42.87660614, -44.97176117, -47.02675152, ...,  -6.58415312,
#         -8.65102798, -13.53255128])]
# [array([[-42.87660614, -44.97176117, -47.02675152, ...,  -6.58415312,
#          -8.65102798, -13.53255128]])]
