# %% [markdown]
# <a href="https://colab.research.google.com/github/shiomasa1218/Colaboratory/blob/master/PCA321.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# drive mean root directory of  google drive
# !ls ./gdrive/'My Drive'/'Kumamoto-Univ'/'Graduationwork'/'exefolder'/'test_folder_name'

# %%
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# check auth
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
cd gdrive/'My Drive'/'Kumamoto-Univ'/'Graduationwork'/'exefolder'/
# Out:
# /content/gdrive/My Drive/Kumamoto-Univ/Graduationwork/exefolder

# %%
import numpy as np
import os
import scipy.fftpack
from pylab import *
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt 
from scipy.signal import butter, filtfilt 
import math
import csv
from sklearn.decomposition import PCA



# 訓練データのフォルダのパス
train_folder_name = "train_folder_name"

# # 検証データのフォルダのパス
# test_folder_name = "test_folder_name"


trainFolder = os.listdir(train_folder_name)
# testFolder = os.listdir(test_folder_name)

os.makedirs("train_pca321",exist_ok=True)
for i,d in enumerate(trainFolder):
   
    if d != ".DS_Store":
        dir_path = 'train_pca321_3/' + d +'_pca321'
        os.makedirs(dir_path,exist_ok=True)
        #フォルダ内のファイルのリストを取得
        files = os.listdir(train_folder_name + '/'+d)
        print(files)
        #ファイル毎にみる
        for f in files:
                            
            #.DS_Storeをどかす
            if f != ".DS_Store":
                #どのファイルを見ているか確認用
                print("load:"+f)

                datafile_path = train_folder_name + '/' + d+'/'+f

                #csvから読み込み
                data = np.loadtxt(datafile_path, delimiter=",")     #pbldata用

                #データ取り出し
                csv_x = data[1, :]
#                 csv_x = csv_x.reshape(len(csv_x),1)
                csv_y = data[2, :]
#                 csv_y = csv_y.reshape(len(csv_x),1)
                csv_z = data[3, :]
#                 csv_y = csv_y.reshape(len(csv_x),1)
                
                csv = []
                csv.append(csv_x)
                csv.append(csv_y)
                csv.append(csv_z)
                csv=np.array(csv)
                csv=csv.T
                
                pca = PCA(n_components = 1)
                pca.fit(csv)
                csv_pca= pca.transform(csv)

#                 # 主成分分析後のサイズ
                print(csv_pca.shape)
                
                csv_pca = csv_pca.reshape(1,len(csv_pca))
                
                PCA321 = []
                
                PCA321.append(csv_pca)
                
                path_w = 'train_pca321_3/' + d +"_pca321" +'/' + f
                path_w = path_w.replace(".csv" , "_pca321.csv")
                np.savetxt(path_w, csv_pca, delimiter=",")
               

            else:
                print(".ds_storeを除去")
    else:
        print("ds_storeを抹殺")
        
print("transformed")
# Out:
# ['twhitetile1_217.csv', 'twhitetile1_216.csv', 'twhitetile1_215.csv', 'twhitetile1_228.csv', 'twhitetile1_229.csv', 'twhitetile1_214.csv', 'twhitetile1_212.csv', 'twhitetile1_213.csv', 'twhitetile1_211.csv', 'twhitetile1_239.csv', 'twhitetile1_276.csv', 'twhitetile1_288.csv', 'twhitetile1_277.csv', 'twhitetile1_28.csv', 'twhitetile1_238.csv', 'twhitetile1_210.csv', 'twhitetile1_263.csv', 'twhitetile1_262.csv', 'twhitetile1_289.csv', 'twhitetile1_265.csv', 'twhitetile1_29.csv', 'twhitetile1_248.csv', 'twhitetile1_249.csv', 'twhitetile1_274.csv', 'twhitetile1_260.csv', 'twhitetile1_261.csv', 'twhitetile1_275.csv', 'twhitetile1_271.csv', 'twhitetile1_259.csv', 'twhitetile1_258.csv', 'twhitetile1_295.csv', 'twhitetile1_270.csv', 'twhitetile1_264.csv', 'twhitetile1_242.csv', 'twhitetile1_273.csv', 'twhitetile1_281.csv', 'twhitetile1_267.csv', 'twhitetile1_21.csv', 'twhitetile1_272.csv', 'twhitetile1_266.csv', 'twhitetile1_256.csv', 'twhitetile1_243.csv', 'twhitetile1_255.csv', 'twhitetile1_257.csv', 'twhitetile1_294.csv', 'twhitetile1_20.csv', 'twhitetile1_280.csv', 'twhitetile1_22.csv', 'twhitetile1_282.csv', 'twhitetile1_269.csv', 'twhitetile1_296.csv', 'twhitetile1_241.csv', 'twhitetile1_240.csv', 'twhitetile1_23.csv', 'twhitetile1_278.csv', 'twhitetile1_27.csv', 'twhitetile1_250.csv', 'twhitetile1_268.csv', 'twhitetile1_254.csv', 'twhitetile1_293.csv', 'twhitetile1_283.csv', 'twhitetile1_287.csv', 'twhitetile1_244.csv', 'twhitetile1_279.csv', 'twhitetile1_245.csv', 'twhitetile1_251.csv', 'twhitetile1_252.csv', 'twhitetile1_286.csv', 'twhitetile1_292.csv', 'twhitetile1_24.csv', 'twhitetile1_290.csv', 'twhitetile1_247.csv', 'twhitetile1_284.csv', 'twhitetile1_253.csv', 'twhitetile1_26.csv', 'twhitetile1_246.csv', 'twhitetile1_285.csv', 'twhitetile1_223.csv', 'twhitetile1_291.csv', 'twhitetile1_221.csv', 'twhitetile1_25.csv', 'twhitetile1_237.csv', 'twhitetile1_235.csv', 'twhitetile1_220.csv', 'twhitetile1_222.csv', 'twhitetile1_236.csv', 'twhitetile1_234.csv', 'twhitetile1_233.csv', 'twhitetile1_227.csv', 'twhitetile1_224.csv', 'twhitetile1_232.csv', 'twhitetile1_226.csv', 'twhitetile1_225.csv', 'twhitetile1_219.csv', 'twhitetile1_230.csv', 'twhitetile1_231.csv', 'twhitetile1_218.csv']
# load:twhitetile1_217.csv
# (2444, 1)
# load:twhitetile1_216.csv
# (2444, 1)
# load:twhitetile1_215.csv
# (2444, 1)
# load:twhitetile1_228.csv
# (2444, 1)
# load:twhitetile1_229.csv
# (2429, 1)
# load:twhitetile1_214.csv
# (2431, 1)
# load:twhitetile1_212.csv
# (2444, 1)
# load:twhitetile1_213.csv
# (2444, 1)
# load:twhitetile1_211.csv
# (2414, 1)
# load:twhitetile1_239.csv
# (2444, 1)
# load:twhitetile1_276.csv
# (2444, 1)
# load:twhitetile1_288.csv
# (2411, 1)
# load:twhitetile1_277.csv
# (2430, 1)
# load:twhitetile1_28.csv
# (2444, 1)
# load:twhitetile1_238.csv
# (2444, 1)
# load:twhitetile1_210.csv
# (2444, 1)
# load:twhitetile1_263.csv
# (2465, 1)
# load:twhitetile1_262.csv
# (2444, 1)
# load:twhitetile1_289.csv
# (2377, 1)
# load:twhitetile1_265.csv
# (2433, 1)
# load:twhitetile1_29.csv
# (2444, 1)
# load:twhitetile1_248.csv
# (2444, 1)
# load:twhitetile1_249.csv
# (2444, 1)
# load:twhitetile1_274.csv
# (2444, 1)
# load:twhitetile1_260.csv
# (2444, 1)
# load:twhitetile1_261.csv
# (2444, 1)
# load:twhitetile1_275.csv
# (2444, 1)
# load:twhitetile1_271.csv
# (2444, 1)
# load:twhitetile1_259.csv
# (2432, 1)
# load:twhitetile1_258.csv
# (2444, 1)
# load:twhitetile1_295.csv
# (2430, 1)
# load:twhitetile1_270.csv
# (2444, 1)
# load:twhitetile1_264.csv
# (1403, 1)
# load:twhitetile1_242.csv
# (2433, 1)
# load:twhitetile1_273.csv
# (2444, 1)
# load:twhitetile1_281.csv
# (2433, 1)
# load:twhitetile1_267.csv
# (2444, 1)
# load:twhitetile1_21.csv
# (2431, 1)
# load:twhitetile1_272.csv
# (2444, 1)
# load:twhitetile1_266.csv
# (2444, 1)
# load:twhitetile1_256.csv
# (2444, 1)
# load:twhitetile1_243.csv
# (2433, 1)
# load:twhitetile1_255.csv
# (2444, 1)
# load:twhitetile1_257.csv
# (2431, 1)
# load:twhitetile1_294.csv
# (2426, 1)
# load:twhitetile1_20.csv
# (1359, 1)
# load:twhitetile1_280.csv
# (2444, 1)
# load:twhitetile1_22.csv
# (2444, 1)
# load:twhitetile1_282.csv
# (2429, 1)
# load:twhitetile1_269.csv
# (2411, 1)
# load:twhitetile1_296.csv
# (2444, 1)
# load:twhitetile1_241.csv
# (2444, 1)
# load:twhitetile1_240.csv
# (2444, 1)
# load:twhitetile1_23.csv
# (2444, 1)
# load:twhitetile1_278.csv
# (2444, 1)
# load:twhitetile1_27.csv
# (2429, 1)
# load:twhitetile1_250.csv
# (2433, 1)
# load:twhitetile1_268.csv
# (2444, 1)
# load:twhitetile1_254.csv
# (2444, 1)
# load:twhitetile1_293.csv
# (2444, 1)
# load:twhitetile1_283.csv
# (2429, 1)
# load:twhitetile1_287.csv
# (2444, 1)
# load:twhitetile1_244.csv
# (2412, 1)
# load:twhitetile1_279.csv
# (2444, 1)
# load:twhitetile1_245.csv
# (2444, 1)
# load:twhitetile1_251.csv
# (2444, 1)
# load:twhitetile1_252.csv
# (2444, 1)
# load:twhitetile1_286.csv
# (2444, 1)
# load:twhitetile1_292.csv
# (2444, 1)
# load:twhitetile1_24.csv
# (2431, 1)
# load:twhitetile1_290.csv
# (2413, 1)
# load:twhitetile1_247.csv
# (2429, 1)
# load:twhitetile1_284.csv
# (2444, 1)
# load:twhitetile1_253.csv
# (2444, 1)
# load:twhitetile1_26.csv
# (2444, 1)
# load:twhitetile1_246.csv
# (2444, 1)
# load:twhitetile1_285.csv
# (2444, 1)
# load:twhitetile1_223.csv
# (2430, 1)
# load:twhitetile1_291.csv
# (2444, 1)
# load:twhitetile1_221.csv
# (2430, 1)
# load:twhitetile1_25.csv
# (2444, 1)
# load:twhitetile1_237.csv
# (2444, 1)
tcarpet1_288.csv', 'tcarpet1_249.csv', 'tcarpet1_21.csv', 'tcarpet1_262.csv', 'tcarpet1_276.csv', 'tcarpet1_298.csv', 'tcarpet1_289.csv', 'tcarpet1_22.csv', 'tcarpet1_299.csv', 'tcarpet1_26.csv', 'tcarpet1_273.csv', 'tcarpet1_272.csv', 'tcarpet1_266.csv', 'tcarpet1_267.csv', 'tcarpet1_27.csv', 'tcarpet1_25.csv', 'tcarpet1_265.csv', 'tcarpet1_271.csv', 'tcarpet1_259.csv', 'tcarpet1_270.csv', 'tcarpet1_258.csv', 'tcarpet1_264.csv', 'tcarpet1_24.csv']
# load:tcarpet1_282.csv
# (2431, 1)
# load:tcarpet1_29.csv
# (2444, 1)
# load:tcarpet1_296.csv
# (2429, 1)
# load:tcarpet1_269.csv
# (2444, 1)
# load:tcarpet1_241.csv
# (2444, 1)
# load:tcarpet1_255.csv
# (2444, 1)
# load:tcarpet1_281.csv
# (2444, 1)
# load:tcarpet1_254.csv
# (2444, 1)
# load:tcarpet1_268.csv
# (2444, 1)
# load:tcarpet1_256.csv
# (2444, 1)
# load:tcarpet1_28.csv
# (2444, 1)
# load:tcarpet1_295.csv
# (2444, 1)
# load:tcarpet1_240.csv
# (2428, 1)
# load:tcarpet1_297.csv
# (2444, 1)
# load:tcarpet1_283.csv
# (2444, 1)
# load:tcarpet1_242.csv
# (2444, 1)
# load:tcarpet1_243.csv
# (2444, 1)
# load:tcarpet1_252.csv
# (2444, 1)
# load:tcarpet1_257.csv
# (2444, 1)
# load:tcarpet1_294.csv
# (2431, 1)
# load:tcarpet1_280.csv
# (2444, 1)
# load:tcarpet1_290.csv
# (2444, 1)
# load:tcarpet1_253.csv
# (2433, 1)
# load:tcarpet1_247.csv
# (2444, 1)
# load:tcarpet1_284.csv
# (2444, 1)
# load:tcarpet1_285.csv
# (2444, 1)
# load:tcarpet1_291.csv
# (2444, 1)
# load:tcarpet1_246.csv
# (2444, 1)
# load:tcarpet1_287.csv
# (2444, 1)
# load:tcarpet1_250.csv
# (2444, 1)
# load:tcarpet1_244.csv
# (2444, 1)
# load:tcarpet1_293.csv
# (2444, 1)
# load:tcarpet1_222.csv
# (2444, 1)
# load:tcarpet1_286.csv
# (2444, 1)
# load:tcarpet1_292.csv
# (2444, 1)
# load:tcarpet1_245.csv
# (2444, 1)
# load:tcarpet1_251.csv
# (2444, 1)
# load:tcarpet1_278.csv
# (2444, 1)
# load:tcarpet1_279.csv
# (2444, 1)
# load:tcarpet1_236.csv
# (2444, 1)
# load:tcarpet1_237.csv
# (1403, 1)
# load:tcarpet1_223.csv
# (2444, 1)
# load:tcarpet1_235.csv
# (2444, 1)
# load:tcarpet1_219.csv
# (2444, 1)
# load:tcarpet1_224.csv
# (2444, 1)
# load:tcarpet1_230.csv
# (2444, 1)
# load:tcarpet1_221.csv
# (2444, 1)
# load:tcarpet1_218.csv
# (2444, 1)
# load:tcarpet1_220.csv
# (2444, 1)
# load:tcarpet1_234.csv
# (2444, 1)
# load:tcarpet1_225.csv
# (2444, 1)
# load:tcarpet1_231.csv
# (2444, 1)
# load:tcarpet1_2103.csv
# (2444, 1)
# load:tcarpet1_227.csv
# (2444, 1)
# load:tcarpet1_232.csv
# (2444, 1)
# load:tcarpet1_217.csv
# (2444, 1)
# load:tcarpet1_233.csv
# (2444, 1)
# load:tcarpet1_2100.csv
# (2444, 1)
# load:tcarpet1_216.csv
# (2444, 1)
# load:tcarpet1_2101.csv
# (2444, 1)
# load:tcarpet1_226.csv
# (2444, 1)
# load:tcarpet1_228.csv
# (2444, 1)
# load:tcarpet1_214.csv
# (2444, 1)
# load:tcarpet1_215.csv
# (2444, 1)
# load:tcarpet1_2104.csv
# (2418, 1)
# load:tcarpet1_229.csv
# (2444, 1)
# load:tcarpet1_211.csv
# (2444, 1)
# load:tcarpet1_2102.csv
# (2433, 1)
# load:tcarpet1_212.csv
# (2444, 1)
# load:tcarpet1_213.csv
# (2444, 1)
# load:tcarpet1_238.csv
# (2444, 1)
# load:tcarpet1_210.csv
# (2444, 1)
# load:tcarpet1_239.csv
# (2444, 1)
# load:tcarpet1_20.csv
# (1344, 1)
# load:tcarpet1_248.csv
# (2444, 1)
# load:tcarpet1_260.csv
# (2444, 1)
# load:tcarpet1_274.csv
# (2444, 1)
# load:tcarpet1_275.csv
# (2444, 1)
# load:tcarpet1_263.csv
# (2444, 1)
# load:tcarpet1_261.csv
# (2444, 1)
# load:tcarpet1_277.csv
# (2444, 1)
# load:tcarpet1_23.csv
# (2444, 1)
# load:tcarpet1_288.csv
# (2433, 1)
# load:tcarpet1_249.csv
# (2444, 1)
# load:tcarpet1_21.csv
# (2444, 1)
# load:tcarpet1_262.csv
# (2444, 1)
# load:tcarpet1_276.csv
# (2429, 1)
# load:tcarpet1_298.csv
# (2444, 1)
# load:tcarpet1_289.csv
# (2433, 1)
# load:tcarpet1_22.csv
# (2433, 1)
# load:tcarpet1_299.csv
# (2444, 1)
# load:tcarpet1_26.csv
# (2444, 1)
# load:tcarpet1_273.csv
# (2444, 1)
# load:tcarpet1_272.csv
# (2431, 1)
# load:tcarpet1_266.csv
# (2444, 1)
# load:tcarpet1_267.csv
# (2431, 1)
# load:tcarpet1_27.csv
# (2444, 1)
# load:tcarpet1_25.csv
# (2444, 1)
# load:tcarpet1_265.csv
# (2444, 1)
# load:tcarpet1_271.csv
# (2444, 1)
# load:tcarpet1_259.csv
# (2444, 1)
# load:tcarpet1_270.csv
# (1388, 1)
# load:tcarpet1_258.csv
# (2444, 1)
# load:tcarpet1_264.csv
# (2444, 1)
# load:tcarpet1_24.csv
# (2444, 1)
# load:tcarpet2_219.csv
# (2425, 1)
# load:tcarpet2_230.csv
# (2444, 1)
# load:tcarpet2_226.csv
# (2430, 1)
# load:tcarpet2_218.csv
# (2433, 1)
# load:tcarpet2_231.csv
# (2433, 1)
# load:tcarpet2_27.csv
# (2444, 1)
# load:tcarpet2_242.csv
# (2444, 1)
# load:tcarpet2_280.csv
# (2414, 1)
# load:tcarpet2_256.csv
# (2444, 1)
# load:tcarpet2_294.csv
# (2444, 1)
# load:tcarpet2_24.csv
# (2444, 1)
# load:tcarpet2_257.csv
# (2429, 1)
# load:tcarpet2_243.csv
# (2444, 1)
# load:tcarpet2_295.csv
# (2444, 1)
# load:tcarpet2_281.csv
# (2444, 1)
# load:tcarpet2_26.csv
# (2444, 1)
# load:tcarpet2_269.csv
# (2444, 1)
# load:tcarpet2_241.csv
# (2444, 1)
# load:tcarpet2_25.csv
# (2444, 1)
# load:tcarpet2_282.csv
# (2444, 1)
# load:tcarpet2_255.csv
# (2444, 1)
# load:tcarpet2_296.csv
# (2444, 1)
# load:tcarpet2_21.csv
# (2444, 1)
# load:tcarpet2_283.csv
# (2444, 1)
# load:tcarpet2_254.csv
# (2444, 1)
# load:tcarpet2_268.csv
# (2444, 1)
# load:tcarpet2_240.csv
# (2430, 1)
# load:tcarpet2_297.csv
# (2444, 1)
# load:tcarpet2_244.csv
# (2444, 1)
# load:tcarpet2_250.csv
# (2444, 1)
# load:tcarpet2_20.csv
# (1300, 1)
# load:tcarpet2_287.csv
# (2444, 1)
# load:tcarpet2_278.csv
# (2444, 1)
# load:tcarpet2_293.csv
# (2444, 1)
# load:tcarpet2_286.csv
# (2444, 1)
# load:tcarpet2_279.csv
# (2444, 1)
# load:tcarpet2_251.csv
# (2444, 1)
# load:tcarpet2_292.csv
# (2444, 1)
# load:tcarpet2_245.csv
# (2444, 1)
# load:tcarpet2_22.csv
# (2430, 1)
# load:tcarpet2_253.csv
# (2430, 1)
# load:tcarpet2_247.csv
# (2444, 1)
# load:tcarpet2_263.csv
# (2444, 1)
# load:tcarpet2_285.csv
# (2444, 1)
# load:tcarpet2_290.csv
# (2444, 1)
# load:tcarpet2_277.csv
# (2429, 1)
# load:tcarpet2_23.csv
# (2444, 1)
# load:tcarpet2_246.csv
# (2433, 1)
# load:tcarpet2_291.csv
# (2444, 1)
# load:tcarpet2_252.csv
# (2444, 1)
# load:tcarpet2_284.csv
# (2444, 1)
# load:tcarpet2_288.csv
# (2444, 1)
# load:tcarpet2_289.csv
# (2444, 1)
# load:tcarpet2_262.csv
# (2433, 1)
# load:tcarpet2_265.csv
# (2444, 1)
# load:tcarpet2_260.csv
# (2444, 1)
# load:tcarpet2_248.csv
# (2444, 1)
# load:tcarpet2_275.csv
# (2444, 1)
# load:tcarpet2_261.csv
# (2444, 1)
# load:tcarpet2_276.csv
# (2444, 1)
# load:tcarpet2_28.csv
# (2433, 1)
# load:tcarpet2_249.csv
# (2444, 1)
# load:tcarpet2_274.csv
# (2444, 1)
# load:tcarpet2_271.csv
# (2433, 1)
# load:tcarpet2_259.csv
# (2424, 1)
# load:tcarpet2_273.csv
# (2432, 1)
# load:tcarpet2_270.csv
# (2444, 1)
# load:tcarpet2_258.csv
# (2433, 1)
# load:tcarpet2_298.csv
# (2444, 1)
# load:tcarpet2_272.csv
# (2431, 1)
# load:tcarpet2_266.csv
# (1374, 1)
# load:tcarpet2_264.csv
# (2444, 1)
# load:tcarpet2_267.csv
# (2444, 1)
# load:tcarpet2_29.csv
# (2444, 1)
# load:tcarpet2_228.csv
# (2444, 1)
# load:tcarpet2_214.csv
# (2433, 1)
# load:tcarpet2_215.csv
# (2444, 1)
# load:tcarpet2_210.csv
# (2444, 1)
# load:tcarpet2_217.csv
# (2444, 1)
# load:tcarpet2_229.csv
# (2444, 1)
# load:tcarpet2_216.csv
# (2444, 1)
# load:tcarpet2_212.csv
# (2430, 1)
# load:tcarpet2_213.csv
# (2444, 1)
# load:tcarpet2_239.csv
# (2432, 1)
# load:tcarpet2_238.csv
# (2444, 1)
# load:tcarpet2_211.csv
# (2444, 1)
# ['tsponge-g_236.csv', 'tsponge-g_222.csv', 'tsponge-g_223.csv', 'tsponge-g_237.csv', 'tsponge-g_235.csv', 'tsponge-g_221.csv', 'tsponge-g_231.csv', 'tsponge-g_224.csv', 'tsponge-g_234.csv', 'tsponge-g_218.csv', 'tsponge-g_220.csv', 'tsponge-g_230.csv', 'tsponge-g_225.csv', 'tsponge-g_219.csv', 'tsponge-g_233.csv', 'tsponge-g_226.csv', 'tsponge-g_241.csv', 'tsponge-g_22.csv', 'tsponge-g_296.csv', 'tsponge-g_255.csv', 'tsponge-g_232.csv', 'tsponge-g_227.csv', 'tsponge-g_282.csv', 'tsponge-g_269.csv', 'tsponge-g_268.csv', 'tsponge-g_242.csv', 'tsponge-g_254.csv', 'tsponge-g_240.csv', 'tsponge-g_256.csv', 'tsponge-g_295.csv', 'tsponge-g_23.csv', 'tsponge-g_283.csv', 'tsponge-g_297.csv', 'tsponge-g_281.csv', 'tsponge-g_21.csv', 'tsponge-g_257.csv', 'tsponge-g_243.csv', 'tsponge-g_252.csv', 'tsponge-g_24.csv', 'tsponge-g_294.csv', 'tsponge-g_280.csv', 'tsponge-g_284.csv', 'tsponge-g_20.csv', 'tsponge-g_247.csv', 'tsponge-g_253.csv', 'tsponge-g_290.csv', 'tsponge-g_291.csv', 'tsponge-g_244.csv', 'tsponge-g_246.csv', 'tsponge-g_285.csv', 'tsponge-g_250.csv', 'tsponge-g_278.csv', 'tsponge-g_293.csv', 'tsponge-g_287.csv', 'tsponge-g_27.csv', 'tsponge-g_25.csv', 'tsponge-g_245.csv', 'tsponge-g_251.csv', 'tsponge-g_286.csv', 'tsponge-g_26.csv', 'tsponge-g_292.csv', 'tsponge-g_279.csv', 'tsponge-g_261.csv', 'tsponge-g_248.csv', 'tsponge-g_274.csv', 'tsponge-g_249.csv', 'tsponge-g_260.csv', 'tsponge-g_275.csv', 'tsponge-g_28.csv', 'tsponge-g_288.csv', 'tsponge-g_272.csv', 'tsponge-g_263.csv', 'tsponge-g_277.csv', 'tsponge-g_276.csv', 'tsponge-g_273.csv', 'tsponge-g_262.csv', 'tsponge-g_289.csv', 'tsponge-g_299.csv', 'tsponge-g_266.csv', 'tsponge-g_29.csv', 'tsponge-g_267.csv', 'tsponge-g_259.csv', 'tsponge-g_214.csv', 'tsponge-g_271.csv', 'tsponge-g_298.csv', 'tsponge-g_265.csv', 'tsponge-g_228.csv', 'tsponge-g_270.csv', 'tsponge-g_216.csv', 'tsponge-g_258.csv', 'tsponge-g_217.csv', 'tsponge-g_264.csv', 'tsponge-g_229.csv', 'tsponge-g_215.csv', 'tsponge-g_239.csv', 'tsponge-g_2101.csv', 'tsponge-g_2100.csv', 'tsponge-g_238.csv', 'tsponge-g_213.csv', 'tsponge-g_211.csv', 'tsponge-g_212.csv', 'tsponge-g_210.csv']
# load:tsponge-g_236.csv
# (2444, 1)
# load:tsponge-g_222.csv
# (2444, 1)
# load:tsponge-g_223.csv
# (2444, 1)
# load:tsponge-g_237.csv
# (2444, 1)
# load:tsponge-g_235.csv
# (2444, 1)
# load:tsponge-g_221.csv
# (2430, 1)
# load:tsponge-g_231.csv
# (2444, 1)
# load:tsponge-g_224.csv
# (2444, 1)
# load:tsponge-g_234.csv
# (1358, 1)
# load:tsponge-g_218.csv
# (2432, 1)
# load:tsponge-g_220.csv
# (2444, 1)
# load:tsponge-g_230.csv
# (2444, 1)
# load:tsponge-g_225.csv
# (2444, 1)
# load:tsponge-g_219.csv
# (2444, 1)
# load:tsponge-g_233.csv
# (2444, 1)
# load:tsponge-g_226.csv
# (2444, 1)
# load:tsponge-g_241.csv
# (2444, 1)
# load:tsponge-g_22.csv
# (2444, 1)
# load:tsponge-g_296.csv
# (2444, 1)
# load:tsponge-g_255.csv
# (2430, 1)
# load:tsponge-g_232.csv
# (2444, 1)
# load:tsponge-g_227.csv
# (2444, 1)
# load:tsponge-g_282.csv
# (2444, 1)
# load:tsponge-g_269.csv
# (2444, 1)
# load:tsponge-g_268.csv
# (1374, 1)
# load:tsponge-g_242.csv
# (2444, 1)
# load:tsponge-g_254.csv
# (2444, 1)
# load:tsponge-g_240.csv
# (2433, 1)
# load:tsponge-g_256.csv
# (2444, 1)
# load:tsponge-g_295.csv
# (2433, 1)
# load:tsponge-g_23.csv
# (2444, 1)
# load:tsponge-g_283.csv
# (2444, 1)
# load:tsponge-g_297.csv
# (2444, 1)
# load:tsponge-g_281.csv
# (2444, 1)
# load:tsponge-g_21.csv
# (2444, 1)
# load:tsponge-g_257.csv
# (2444, 1)
# load:tsponge-g_243.csv
# (2444, 1)
# load:tsponge-g_252.csv
# (2444, 1)
# load:tsponge-g_24.csv
# (2444, 1)
# load:tsponge-g_294.csv
# (2444, 1)
# load:tsponge-g_280.csv
# (2444, 1)
# load:tsponge-g_284.csv
# (2444, 1)
# load:tsponge-g_20.csv
# (1359, 1)
# load:tsponge-g_247.csv
# (2444, 1)
# load:tsponge-g_253.csv
# (2444, 1)
# load:tsponge-g_290.csv
# (2444, 1)
# load:tsponge-g_291.csv
# (2444, 1)
# load:tsponge-g_244.csv
# (2444, 1)
# load:tsponge-g_246.csv
# (2444, 1)
# load:tsponge-g_285.csv
# (2444, 1)
# load:tsponge-g_250.csv
# (2444, 1)
# load:tsponge-g_278.csv
# (2431, 1)
# load:tsponge-g_293.csv
# (2444, 1)
# load:tsponge-g_287.csv
# (2444, 1)
# load:tsponge-g_27.csv
# (2444, 1)
# load:tsponge-g_25.csv
# (2444, 1)
# load:tsponge-g_245.csv
# (2444, 1)
# load:tsponge-g_251.csv
# (2425, 1)
# load:tsponge-g_286.csv
# (2444, 1)
# load:tsponge-g_26.csv
# (2444, 1)
# load:tsponge-g_292.csv
# (2444, 1)
# load:tsponge-g_279.csv
# (2444, 1)
# load:tsponge-g_261.csv
# (2444, 1)
# load:tsponge-g_248.csv
# (2444, 1)
# load:tsponge-g_274.csv
# (2416, 1)
# load:tsponge-g_249.csv
# (2444, 1)
# load:tsponge-g_260.csv
# (2444, 1)
# load:tsponge-g_275.csv
# (2444, 1)
# load:tsponge-g_28.csv
# (2433, 1)
# load:tsponge-g_288.csv
# (2444, 1)
# load:tsponge-g_272.csv
# (2444, 1)
# load:tsponge-g_263.csv
# (2444, 1)
# load:tsponge-g_277.csv
# (2444, 1)
# load:tsponge-g_276.csv
# (2413, 1)
# load:tsponge-g_273.csv
# (2444, 1)
# load:tsponge-g_262.csv
# (2444, 1)
# load:tsponge-g_289.csv
# (2444, 1)
# load:tsponge-g_299.csv
# (2444, 1)
# load:tsponge-g_266.csv
# (2444, 1)
# load:tsponge-g_29.csv
# (2433, 1)
# load:tsponge-g_267.csv
# (2444, 1)
# load:tsponge-g_259.csv
# (2444, 1)
# load:tsponge-g_214.csv
# (2444, 1)
# load:tsponge-g_271.csv
# (2444, 1)
# load:tsponge-g_298.csv
# (2444, 1)
# load:tsponge-g_265.csv
# (2432, 1)
# load:tsponge-g_228.csv
# (2444, 1)
# load:tsponge-g_270.csv
# (2444, 1)
# load:tsponge-g_216.csv
# (2444, 1)
# load:tsponge-g_258.csv
# (2444, 1)
# load:tsponge-g_217.csv
# (2444, 1)
# load:tsponge-g_264.csv
# (2444, 1)
# load:tsponge-g_229.csv
# (2444, 1)
# load:tsponge-g_215.csv
# (2444, 1)
# load:tsponge-g_239.csv
# (2444, 1)
# load:tsponge-g_2101.csv
# (2437, 1)
# load:tsponge-g_2100.csv
# (2444, 1)
# load:tsponge-g_238.csv
# (2444, 1)
# load:tsponge-g_213.csv
# (2444, 1)
# load:tsponge-g_211.csv
# (2444, 1)
# load:tsponge-g_212.csv
# (2444, 1)
# load:tsponge-g_210.csv
# (2444, 1)
# (2444, 1)
# load:twoodtile1_212.csv
# (2444, 1)
# load:twoodtile1_238.csv
# (2444, 1)
# load:twoodtile1_217.csv
# (2444, 1)
# load:twoodtile1_211.csv
# (2431, 1)
# load:twoodtile1_276.csv
# (2444, 1)
# load:twoodtile1_260.csv
# (2424, 1)
# load:twoodtile1_262.csv
# (2444, 1)
# load:twoodtile1_277.csv
# (2444, 1)
# load:twoodtile1_289.csv
# (2433, 1)
# load:twoodtile1_263.csv
# (2444, 1)
# load:twoodtile1_249.csv
# (2444, 1)
# load:twoodtile1_288.csv
# (2444, 1)
# load:twoodtile1_261.csv
# (2444, 1)
# load:twoodtile1_275.csv
# (2444, 1)
# load:twoodtile1_274.csv
# (2444, 1)
# load:twoodtile1_248.csv
# (2444, 1)
# load:twoodtile1_264.csv
# (2444, 1)
# load:twoodtile1_259.csv
# (2429, 1)
# load:twoodtile1_270.csv
# (2444, 1)
# load:twoodtile1_299.csv
# (2444, 1)
# load:twoodtile1_273.csv
# (2444, 1)
# load:twoodtile1_258.csv
# (2444, 1)
# load:twoodtile1_271.csv
# (2444, 1)
# load:twoodtile1_265.csv
# (2444, 1)
# load:twoodtile1_298.csv
# (2444, 1)
# load:twoodtile1_272.csv
# (2444, 1)
# load:twoodtile1_267.csv
# (2430, 1)
# load:twoodtile1_266.csv
# (1359, 1)
# load:twoodtile1_257.csv
# (2444, 1)
# load:twoodtile1_295.csv
# (2444, 1)
# load:twoodtile1_280.csv
# (2444, 1)
# load:twoodtile1_243.csv
# (2430, 1)
# load:twoodtile1_254.csv
# (2425, 1)
# load:twoodtile1_242.csv
# (2444, 1)
# load:twoodtile1_294.csv
# (2444, 1)
# load:twoodtile1_281.csv
# (2444, 1)
# load:twoodtile1_256.csv
# (2444, 1)
# load:twoodtile1_268.csv
# (2444, 1)
# load:twoodtile1_240.csv
# (2444, 1)
# load:twoodtile1_283.csv
# (2444, 1)
# load:twoodtile1_279.csv
# (2444, 1)
# load:twoodtile1_297.csv
# (2433, 1)
# load:twoodtile1_296.csv
# (2444, 1)
# load:twoodtile1_251.csv
# (2444, 1)
# load:twoodtile1_269.csv
# (2444, 1)
# load:twoodtile1_282.csv
# (2444, 1)
# load:twoodtile1_245.csv
# (2429, 1)
# load:twoodtile1_255.csv
# (2444, 1)
# load:twoodtile1_241.csv
# (2416, 1)
# load:twoodtile1_292.csv
# (2444, 1)
# load:twoodtile1_286.csv
# (2444, 1)
# load:twoodtile1_293.csv
# (2444, 1)
# load:twoodtile1_278.csv
# (2433, 1)
# load:twoodtile1_287.csv
# (2444, 1)
# load:twoodtile1_290.csv
# (2444, 1)
# load:twoodtile1_250.csv
# (2444, 1)
# load:twoodtile1_252.csv
# (2444, 1)
# load:twoodtile1_285.csv
# (2430, 1)
# load:twoodtile1_291.csv
# (2444, 1)
# load:twoodtile1_244.csv
# (2444, 1)
# load:twoodtile1_246.csv
# (2426, 1)
# load:twoodtile1_284.csv
# (2444, 1)
# load:twoodtile1_253.csv
# (2444, 1)
# load:twoodtile1_220.csv
# (2444, 1)
# load:twoodtile1_247.csv
# (2444, 1)
# load:twoodtile1_234.csv
# (2444, 1)
# load:twoodtile1_22.csv
# (2444, 1)
# load:twoodtile1_23.csv
# (2444, 1)
# load:twoodtile1_235.csv
# (2444, 1)
# load:twoodtile1_20.csv
# (1330, 1)
# load:twoodtile1_237.csv
# (2444, 1)
# load:twoodtile1_221.csv
# (2444, 1)
# load:twoodtile1_21.csv
# (2416, 1)
# load:twoodtile1_223.csv
# (2444, 1)
# load:twoodtile1_222.csv
# (2444, 1)
# load:twoodtile1_232.csv
# (2444, 1)
# load:twoodtile1_219.csv
# (2444, 1)
# load:twoodtile1_236.csv
# (2444, 1)
# load:twoodtile1_226.csv
# (2444, 1)
# load:twoodtile1_233.csv
# (1330, 1)
# load:twoodtile1_225.csv
# (2430, 1)
# load:twoodtile1_231.csv
# (2444, 1)
# load:twoodtile1_26.csv
# (2444, 1)
# load:twoodtile1_27.csv
# (2444, 1)
# load:twoodtile1_227.csv
# (2444, 1)
# load:twoodtile1_24.csv
# (2444, 1)
# load:twoodtile1_25.csv
# (2444, 1)
# load:twoodtile1_218.csv
# (2426, 1)
# load:twoodtile1_230.csv
# (2444, 1)
# load:twoodtile1_224.csv
# (2429, 1)
# ['tcarpet3_218.csv', 'tcarpet3_224.csv', 'tcarpet3_230.csv', 'tcarpet3_231.csv', 'tcarpet3_223.csv', 'tcarpet3_225.csv', 'tcarpet3_219.csv', 'tcarpet3_227.csv', 'tcarpet3_236.csv', 'tcarpet3_226.csv', 'tcarpet3_232.csv', 'tcarpet3_233.csv', 'tcarpet3_222.csv', 'tcarpet3_237.csv', 'tcarpet3_2100.csv', 'tcarpet3_29.csv', 'tcarpet3_221.csv', 'tcarpet3_235.csv', 'tcarpet3_290.csv', 'tcarpet3_234.csv', 'tcarpet3_284.csv', 'tcarpet3_28.csv', 'tcarpet3_253.csv', 'tcarpet3_220.csv', 'tcarpet3_247.csv', 'tcarpet3_291.csv', 'tcarpet3_285.csv', 'tcarpet3_252.csv', 'tcarpet3_278.csv', 'tcarpet3_246.csv', 'tcarpet3_245.csv', 'tcarpet3_287.csv', 'tcarpet3_293.csv', 'tcarpet3_244.csv', 'tcarpet3_292.csv', 'tcarpet3_250.csv', 'tcarpet3_286.csv', 'tcarpet3_251.csv', 'tcarpet3_279.csv', 'tcarpet3_255.csv', 'tcarpet3_254.csv', 'tcarpet3_268.csv', 'tcarpet3_283.csv', 'tcarpet3_282.csv', 'tcarpet3_296.csv', 'tcarpet3_297.csv', 'tcarpet3_269.csv', 'tcarpet3_240.csv', 'tcarpet3_241.csv', 'tcarpet3_242.csv', 'tcarpet3_256.csv', 'tcarpet3_299.csv', 'tcarpet3_295.csv', 'tcarpet3_294.csv', 'tcarpet3_281.csv', 'tcarpet3_298.csv', 'tcarpet3_280.csv', 'tcarpet3_272.csv', 'tcarpet3_257.csv', 'tcarpet3_243.csv', 'tcarpet3_266.csv', 'tcarpet3_267.csv', 'tcarpet3_260.csv', 'tcarpet3_273.csv', 'tcarpet3_259.csv', 'tcarpet3_248.csv', 'tcarpet3_270.csv', 'tcarpet3_271.csv', 'tcarpet3_274.csv', 'tcarpet3_258.csv', 'tcarpet3_265.csv', 'tcarpet3_264.csv', 'tcarpet3_249.csv', 'tcarpet3_261.csv', 'tcarpet3_239.csv', 'tcarpet3_275.csv', 'tcarpet3_263.csv', 'tcarpet3_211.csv', 'tcarpet3_288.csv', 'tcarpet3_25.csv', 'tcarpet3_289.csv', 'tcarpet3_276.csv', 'tcarpet3_277.csv', 'tcarpet3_262.csv', 'tcarpet3_210.csv', 'tcarpet3_238.csv', 'tcarpet3_22.csv', 'tcarpet3_24.csv', 'tcarpet3_212.csv', 'tcarpet3_26.csv', 'tcarpet3_27.csv', 'tcarpet3_23.csv', 'tcarpet3_217.csv', 'tcarpet3_213.csv', 'tcarpet3_216.csv', 'tcarpet3_20.csv', 'tcarpet3_214.csv', 'tcarpet3_228.csv', 'tcarpet3_21.csv', 'tcarpet3_215.csv', 'tcarpet3_229.csv']
# load:tcarpet3_218.csv
# (2444, 1)
# load:tcarpet3_224.csv
# (2444, 1)
# load:tcarpet3_230.csv
# (2444, 1)
# load:tcarpet3_231.csv
# (2444, 1)
# load:tcarpet3_223.csv
# (2444, 1)
# load:tcarpet3_225.csv
# (2444, 1)
# load:tcarpet3_219.csv
# (2444, 1)
# load:tcarpet3_227.csv
# (2444, 1)
# load:tcarpet3_236.csv
# (2444, 1)
# load:tcarpet3_226.csv
# (2444, 1)
# load:tcarpet3_232.csv
# (2444, 1)
# load:tcarpet3_233.csv
# (2692, 1)
# load:tcarpet3_222.csv
# (2444, 1)
# load:tcarpet3_237.csv
# (2444, 1)
# load:tcarpet3_2100.csv
# (2444, 1)
# load:tcarpet3_29.csv
# (2444, 1)
# load:tcarpet3_221.csv
# (2444, 1)
# load:tcarpet3_235.csv
# (2433, 1)
# load:tcarpet3_290.csv
# (2444, 1)
# load:tcarpet3_234.csv
# (1374, 1)
# load:tcarpet3_284.csv
# (2444, 1)
# load:tcarpet3_28.csv
# (2444, 1)
# load:tcarpet3_253.csv
# (2444, 1)
# load:tcarpet3_220.csv
# (2444, 1)
# load:tcarpet3_247.csv
# (2431, 1)
# load:tcarpet3_291.csv
# (2444, 1)
# load:tcarpet3_285.csv
# (2444, 1)
# load:tcarpet3_252.csv
# (2444, 1)
# load:tcarpet3_278.csv
# (2444, 1)
# load:tcarpet3_246.csv
# (2444, 1)
# load:tcarpet3_245.csv
# (2431, 1)
# load:tcarpet3_287.csv
# (2433, 1)
# load:tcarpet3_293.csv
# (2444, 1)
# load:tcarpet3_244.csv
# (2444, 1)
# load:tcarpet3_292.csv
# (2444, 1)
# load:tcarpet3_250.csv
# (2444, 1)
# load:tcarpet3_286.csv
# (2444, 1)
# load:tcarpet3_251.csv
# (2444, 1)
# load:tcarpet3_279.csv
# (2444, 1)
# load:tcarpet3_255.csv
# (2444, 1)
# load:tcarpet3_254.csv
# (2444, 1)
# load:tcarpet3_268.csv
# (1374, 1)
# load:tcarpet3_283.csv
# (2432, 1)
# load:tcarpet3_282.csv
# (2444, 1)
# load:tcarpet3_296.csv
# (2444, 1)
# load:tcarpet3_297.csv
# (2444, 1)
# load:tcarpet3_269.csv
# (2444, 1)
# load:tcarpet3_240.csv
# (2444, 1)
# load:tcarpet3_241.csv
# (2444, 1)
# load:tcarpet3_242.csv
# (2432, 1)
# load:tcarpet3_256.csv
# (2444, 1)
# load:tcarpet3_299.csv
# (2444, 1)
# load:tcarpet3_295.csv
# (2444, 1)
# load:tcarpet3_294.csv
# (2433, 1)
# load:tcarpet3_281.csv
# (2433, 1)
# load:tcarpet3_298.csv
# (2444, 1)
# load:tcarpet3_280.csv
# (2444, 1)
# load:tcarpet3_272.csv
# (2444, 1)
# load:tcarpet3_257.csv
# (2444, 1)
# load:tcarpet3_243.csv
# (2444, 1)
# load:tcarpet3_266.csv
# (2444, 1)
# load:tcarpet3_267.csv
# (2445, 1)
# load:tcarpet3_260.csv
# (2444, 1)
# load:tcarpet3_273.csv
# (2444, 1)
# load:tcarpet3_259.csv
# (2444, 1)
# load:tcarpet3_248.csv
# (2444, 1)
# load:tcarpet3_270.csv
# (2444, 1)
# load:tcarpet3_271.csv
# (2444, 1)
# load:tcarpet3_274.csv
# (2444, 1)
# load:tcarpet3_258.csv
# (2444, 1)
# load:tcarpet3_265.csv
# (2444, 1)
# load:tcarpet3_264.csv
# (2444, 1)
# load:tcarpet3_249.csv
# (2444, 1)
# load:tcarpet3_261.csv
# (2444, 1)
# load:tcarpet3_239.csv
# (2444, 1)
# load:tcarpet3_275.csv
# (2444, 1)
# load:tcarpet3_263.csv
# (2444, 1)
# load:tcarpet3_211.csv
# (2444, 1)
# load:tcarpet3_288.csv
# (2444, 1)
# load:tcarpet3_25.csv
# (2444, 1)
# load:tcarpet3_289.csv
# (2444, 1)
# load:tcarpet3_276.csv
# (2444, 1)
# load:tcarpet3_277.csv
# (2444, 1)
# load:tcarpet3_262.csv
# (2444, 1)
# load:tcarpet3_210.csv
# (2444, 1)
# load:tcarpet3_238.csv
# (2444, 1)
# load:tcarpet3_22.csv
# (2444, 1)
# load:tcarpet3_24.csv
# (2444, 1)
# load:tcarpet3_212.csv
# (2444, 1)
# load:tcarpet3_26.csv
# (2444, 1)
# load:tcarpet3_27.csv
# (2444, 1)
# load:tcarpet3_23.csv
# (2444, 1)
# load:tcarpet3_217.csv
# (2444, 1)
# load:tcarpet3_213.csv
# (2444, 1)
# load:tcarpet3_216.csv
# (2444, 1)
# load:tcarpet3_20.csv
# (1359, 1)
# load:tcarpet3_214.csv
# (2444, 1)
# load:tcarpet3_228.csv
# (2444, 1)
# load:tcarpet3_21.csv
# (2444, 1)
# load:tcarpet3_215.csv
# (2429, 1)
# load:tcarpet3_229.csv
# (2444, 1)
# (2444, 1)
# load:tsponge-y_245.csv
# (2430, 1)
# load:tsponge-y_292.csv
# (2444, 1)
# load:tsponge-y_246.csv
# (2444, 1)
# load:tsponge-y_290.csv
# (2444, 1)
# load:tsponge-y_279.csv
# (2444, 1)
# load:tsponge-y_252.csv
# (2444, 1)
# load:tsponge-y_284.csv
# (2444, 1)
# load:tsponge-y_22.csv
# (2444, 1)
# load:tsponge-y_253.csv
# (2444, 1)
# load:tsponge-y_247.csv
# (2444, 1)
# load:tsponge-y_286.csv
# (2444, 1)
# load:tsponge-y_23.csv
# (2444, 1)
# load:tsponge-y_285.csv
# (2444, 1)
# load:tsponge-y_280.csv
# (2431, 1)
# load:tsponge-y_295.csv
# (2444, 1)
# load:tsponge-y_256.csv
# (2444, 1)
# load:tsponge-y_291.csv
# (2444, 1)
# load:tsponge-y_281.csv
# (2444, 1)
# load:tsponge-y_294.csv
# (2444, 1)
# load:tsponge-y_242.csv
# (2431, 1)
# load:tsponge-y_26.csv
# (2429, 1)
# load:tsponge-y_27.csv
# (2444, 1)
# load:tsponge-y_243.csv
# (2444, 1)
# load:tsponge-y_257.csv
# (2444, 1)
# load:tsponge-y_282.csv
# (2396, 1)
# load:tsponge-y_296.csv
# (2444, 1)
# load:tsponge-y_297.csv
# (2444, 1)
# load:tsponge-y_255.csv
# (2432, 1)
# load:tsponge-y_241.csv
# (2444, 1)
# load:tsponge-y_240.csv
# (2444, 1)
# load:tsponge-y_254.csv
# (2444, 1)
# load:tsponge-y_268.csv
# (2444, 1)
# load:tsponge-y_24.csv
# (2444, 1)
# load:tsponge-y_25.csv
# (2412, 1)
# load:tsponge-y_269.csv
# (2444, 1)
# load:tsponge-y_283.csv
# (2444, 1)
# load:tsponge-y_232.csv
# (2444, 1)
# load:tsponge-y_219.csv
# (2416, 1)
# load:tsponge-y_227.csv
# (2429, 1)
# load:tsponge-y_233.csv
# (2444, 1)
# load:tsponge-y_235.csv
# (2428, 1)
# load:tsponge-y_224.csv
# (2444, 1)
# load:tsponge-y_218.csv
# (2433, 1)
# load:tsponge-y_231.csv
# (2433, 1)
# load:tsponge-y_226.csv
# (2444, 1)
# load:tsponge-y_225.csv
# (2432, 1)
# load:tsponge-y_230.csv
# (2427, 1)
# load:tsponge-y_221.csv
# (2444, 1)
# load:tsponge-y_237.csv
# (2433, 1)
# load:tsponge-y_211.csv
# (2444, 1)
# load:tsponge-y_222.csv
# (2444, 1)
# load:tsponge-y_234.csv
# (1374, 1)
# load:tsponge-y_213.csv
# (2444, 1)
# load:tsponge-y_239.csv
# (2433, 1)
# load:tsponge-y_236.csv
# (2444, 1)
# load:tsponge-y_212.csv
# (2444, 1)
# load:tsponge-y_220.csv
# (2444, 1)
# load:tsponge-y_223.csv
# (2444, 1)
# load:tsponge-y_210.csv
# (2444, 1)
# load:tsponge-y_214.csv
# (2444, 1)
# load:tsponge-y_271.csv
# (2444, 1)
# load:tsponge-y_228.csv
# (2444, 1)
# load:tsponge-y_229.csv
# (2444, 1)
# load:tsponge-y_238.csv
# (2433, 1)
# load:tsponge-y_28.csv
# (2444, 1)
# load:tsponge-y_217.csv
# (2432, 1)
# load:tsponge-y_215.csv
# (2444, 1)
# load:tsponge-y_216.csv
# (2444, 1)
# load:tsponge-y_259.csv
# (2444, 1)
# load:tsponge-y_265.csv
# (2433, 1)
# load:tsponge-y_29.csv
# (2444, 1)
# load:tsponge-y_264.csv
# (2444, 1)
# load:tsponge-y_277.csv
# (2444, 1)
# load:tsponge-y_258.csv
# (2444, 1)
# load:tsponge-y_270.csv
# (2444, 1)
# load:tsponge-y_263.csv
# (2444, 1)
# load:tsponge-y_272.csv
# (2444, 1)
# load:tsponge-y_273.csv
# (2444, 1)
# load:tsponge-y_266.csv
# (2444, 1)
# load:tsponge-y_267.csv
# (1359, 1)
# load:tsponge-y_298.csv
# (2444, 1)
# load:tsponge-y_288.csv
# (2444, 1)
# load:tsponge-y_262.csv
# (2444, 1)
# load:tsponge-y_276.csv
# (2444, 1)
# load:tsponge-y_275.csv
# (2444, 1)
# load:tsponge-y_274.csv
# (2444, 1)
# load:tsponge-y_260.csv
# (2444, 1)
# load:tsponge-y_261.csv
# (2444, 1)
# load:tsponge-y_248.csv
# (2433, 1)
# load:tsponge-y_249.csv
# (2444, 1)
# load:tsponge-y_289.csv
# (2444, 1)
# ['tstonetile1_237.csv', 'tstonetile1_235.csv', 'tstonetile1_223.csv', 'tstonetile1_29.csv', 'tstonetile1_236.csv', 'tstonetile1_28.csv', 'tstonetile1_221.csv', 'tstonetile1_220.csv', 'tstonetile1_222.csv', 'tstonetile1_234.csv', 'tstonetile1_231.csv', 'tstonetile1_225.csv', 'tstonetile1_218.csv', 'tstonetile1_219.csv', 'tstonetile1_224.csv', 'tstonetile1_240.csv', 'tstonetile1_226.csv', 'tstonetile1_230.csv', 'tstonetile1_233.csv', 'tstonetile1_227.csv', 'tstonetile1_232.csv', 'tstonetile1_268.csv', 'tstonetile1_254.csv', 'tstonetile1_283.csv', 'tstonetile1_297.csv', 'tstonetile1_280.csv', 'tstonetile1_296.csv', 'tstonetile1_282.csv', 'tstonetile1_294.csv', 'tstonetile1_255.csv', 'tstonetile1_269.csv', 'tstonetile1_243.csv', 'tstonetile1_257.csv', 'tstonetile1_241.csv', 'tstonetile1_281.csv', 'tstonetile1_295.csv', 'tstonetile1_242.csv', 'tstonetile1_256.csv', 'tstonetile1_252.csv', 'tstonetile1_246.csv', 'tstonetile1_290.csv', 'tstonetile1_285.csv', 'tstonetile1_284.csv', 'tstonetile1_291.csv', 'tstonetile1_247.csv', 'tstonetile1_253.csv', 'tstonetile1_245.csv', 'tstonetile1_279.csv', 'tstonetile1_286.csv', 'tstonetile1_251.csv', 'tstonetile1_250.csv', 'tstonetile1_293.csv', 'tstonetile1_292.csv', 'tstonetile1_287.csv', 'tstonetile1_278.csv', 'tstonetile1_244.csv', 'tstonetile1_249.csv', 'tstonetile1_261.csv', 'tstonetile1_263.csv', 'tstonetile1_274.csv', 'tstonetile1_275.csv', 'tstonetile1_276.csv', 'tstonetile1_260.csv', 'tstonetile1_289.csv', 'tstonetile1_248.csv', 'tstonetile1_288.csv', 'tstonetile1_262.csv', 'tstonetile1_277.csv', 'tstonetile1_273.csv', 'tstonetile1_267.csv', 'tstonetile1_265.csv', 'tstonetile1_298.csv', 'tstonetile1_266.csv', 'tstonetile1_272.csv', 'tstonetile1_216.csv', 'tstonetile1_264.csv', 'tstonetile1_259.csv', 'tstonetile1_270.csv', 'tstonetile1_258.csv', 'tstonetile1_271.csv', 'tstonetile1_20.csv', 'tstonetile1_217.csv', 'tstonetile1_238.csv', 'tstonetile1_21.csv', 'tstonetile1_215.csv', 'tstonetile1_229.csv', 'tstonetile1_26.csv', 'tstonetile1_22.csv', 'tstonetile1_214.csv', 'tstonetile1_228.csv', 'tstonetile1_210.csv', 'tstonetile1_23.csv', 'tstonetile1_27.csv', 'tstonetile1_239.csv', 'tstonetile1_213.csv', 'tstonetile1_211.csv', 'tstonetile1_24.csv', 'tstonetile1_25.csv', 'tstonetile1_212.csv']
# load:tstonetile1_237.csv
# (2444, 1)
# load:tstonetile1_235.csv
# (2444, 1)
# load:tstonetile1_223.csv
# (2429, 1)
# load:tstonetile1_29.csv
# (2444, 1)
# load:tstonetile1_236.csv
# (2444, 1)
# load:tstonetile1_28.csv
# (2431, 1)
# load:tstonetile1_221.csv
# (2444, 1)
# load:tstonetile1_220.csv
# (2444, 1)
# load:tstonetile1_222.csv
# (2444, 1)
# load:tstonetile1_234.csv
# (2416, 1)
# load:tstonetile1_231.csv
# (2444, 1)
# load:tstonetile1_225.csv
# (2433, 1)
# load:tstonetile1_218.csv
# (2444, 1)
# load:tstonetile1_219.csv
# (2444, 1)
# load:tstonetile1_224.csv
# (2444, 1)
# load:tstonetile1_240.csv
# (2444, 1)
# load:tstonetile1_226.csv
# (2444, 1)
# load:tstonetile1_230.csv
# (2444, 1)
# load:tstonetile1_233.csv
# (1286, 1)
# load:tstonetile1_227.csv
# (2444, 1)
# load:tstonetile1_232.csv
# (2444, 1)
# load:tstonetile1_268.csv
# (2431, 1)
# load:tstonetile1_254.csv
# (2444, 1)
# load:tstonetile1_283.csv
# (2444, 1)
# load:tstonetile1_297.csv
# (2444, 1)
# load:tstonetile1_280.csv
# (2444, 1)
# load:tstonetile1_296.csv
# (2444, 1)
# load:tstonetile1_282.csv
# (2444, 1)
# load:tstonetile1_294.csv
# (2417, 1)
# load:tstonetile1_255.csv
# (2431, 1)
# load:tstonetile1_269.csv
# (2444, 1)
# load:tstonetile1_243.csv
# (2444, 1)
# load:tstonetile1_257.csv
# (2444, 1)
# load:tstonetile1_241.csv
# (2444, 1)
# load:tstonetile1_281.csv
# (2444, 1)
# load:tstonetile1_295.csv
# (2444, 1)
# load:tstonetile1_242.csv
# (2444, 1)
# load:tstonetile1_256.csv
# (2444, 1)
# load:tstonetile1_252.csv
# (2444, 1)
# load:tstonetile1_246.csv
# (2444, 1)
# load:tstonetile1_290.csv
# (2444, 1)
# load:tstonetile1_285.csv
# (2444, 1)
# load:tstonetile1_284.csv
# (2444, 1)
# load:tstonetile1_291.csv
# (2444, 1)
# load:tstonetile1_247.csv
# (2444, 1)
# load:tstonetile1_253.csv
# (2413, 1)
# load:tstonetile1_245.csv
# (2430, 1)
# load:tstonetile1_279.csv
# (2444, 1)
# load:tstonetile1_286.csv
# (2444, 1)
# load:tstonetile1_251.csv
# (2444, 1)
# load:tstonetile1_250.csv
# (2414, 1)
# load:tstonetile1_293.csv
# (2444, 1)
# load:tstonetile1_292.csv
# (2444, 1)
# load:tstonetile1_287.csv
# (2444, 1)
# load:tstonetile1_278.csv
# (2444, 1)
# load:tstonetile1_244.csv
# (2444, 1)
# load:tstonetile1_249.csv
# (2414, 1)
# load:tstonetile1_261.csv
# (2444, 1)
# load:tstonetile1_263.csv
# (2418, 1)
# load:tstonetile1_274.csv
# (2444, 1)
# load:tstonetile1_275.csv
# (2444, 1)
# load:tstonetile1_276.csv
# (2444, 1)
# load:tstonetile1_260.csv
# (2444, 1)
# load:tstonetile1_289.csv
# (2444, 1)
# load:tstonetile1_248.csv
# (2444, 1)
# load:tstonetile1_288.csv
# (2430, 1)
# load:tstonetile1_262.csv
# (2428, 1)
# load:tstonetile1_277.csv
# (2444, 1)
# load:tstonetile1_273.csv
# (2412, 1)
# load:tstonetile1_267.csv
# (2444, 1)
# load:tstonetile1_265.csv
# (2444, 1)
# load:tstonetile1_298.csv
# (2444, 1)
# load:tstonetile1_266.csv
# (1315, 1)
# load:tstonetile1_272.csv
# (2444, 1)
# load:tstonetile1_216.csv
# (2429, 1)
# load:tstonetile1_264.csv
# (2444, 1)
# load:tstonetile1_259.csv
# (2444, 1)
# load:tstonetile1_270.csv
# (2444, 1)
# load:tstonetile1_258.csv
# (2444, 1)
# load:tstonetile1_271.csv
# (2444, 1)
# load:tstonetile1_20.csv
# (1315, 1)
# load:tstonetile1_217.csv
# (2444, 1)
# load:tstonetile1_238.csv
# (2444, 1)
# load:tstonetile1_21.csv
# (2444, 1)
# load:tstonetile1_215.csv
# (2431, 1)
# load:tstonetile1_229.csv
# (2444, 1)
# load:tstonetile1_26.csv
# (2444, 1)
# load:tstonetile1_22.csv
# (2444, 1)
# load:tstonetile1_214.csv
# (2444, 1)
# load:tstonetile1_228.csv
# (2432, 1)
# load:tstonetile1_210.csv
# (2444, 1)
# load:tstonetile1_23.csv
# (2444, 1)
# load:tstonetile1_27.csv
# (2444, 1)
# load:tstonetile1_239.csv
# (2444, 1)
# load:tstonetile1_213.csv
# (2444, 1)
# load:tstonetile1_211.csv
# (2444, 1)
# load:tstonetile1_24.csv
# (2444, 1)
# load:tstonetile1_25.csv
# (2433, 1)
# load:tstonetile1_212.csv
# (2431, 1)
# ds_storeを抹殺
# transformed

# %%
print(csv_pca)
print(csv_pca.shape)
# Out:
# [[103.04843139 102.471037   100.58492199 ...  54.26234833  61.0142042
#    78.15717279]]
# (1, 2431)
